# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
import pylab as py
import sys
import numpy.ma as ma
from decimal import Decimal
import sqlite3
import pandas as pd
import os
from importlib import reload
from matplotlib import animation, rc
import matplotlib.animation as animationη
from matplotlib.ticker import FormatStrFormatter
import types
from IPython.display import HTML
import blobs
import warnings

# %%
H = blobs.blob_history(600,883)

# %%
blobs.area_dist(600,883)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
import ffmpeg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-16f5f3b4de71> in <module>
# ----> 1 import ffmpeg
#
# ModuleNotFoundError: No module named 'ffmpeg'

# %%
blobs.amplitude_dist(600,883)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
blobs.position_distribution(600,883)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
blobs.vel_vs_pos(H)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
blobs.total_velocity_distributions(H)

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
blobs.amplitude_velocity(H)

# %%
blobs.birth_distribution(H)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
blobs.vel_vs_pol_pos(H)

# %%
ne_mid = np.load('/global/cscratch1/sd/giannos/ti262_arrays/ne_mid.npy')

# %%
blobs.flux_vs_pos(ne_mid,H)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/numpy/lib/function_base.py:731: RuntimeWarning: divide by zero encountered in double_scalars
#   norm = bins / (mx - mn)
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/numpy/lib/function_base.py:756: RuntimeWarning: invalid value encountered in multiply
#   tmp_a *= norm
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-8bbe19eceeae> in <module>
# ----> 1 blobs.flux_vs_pos(ne_mid,H)
#
# /global/u1/g/giannos/xgc_python_dir/blobs.py in flux_vs_pos(arr_mid, H)
#    2073     ax2.legend(loc=7)
#    2074     ax3.set_title(r"Flux distribution, $1.000<\Psi_N<1.005$")
# -> 2075     ax3.hist(flux_3,bins='auto',color='blue')
#    2076     ax3.axvline(x=flux_m3,color='r',label='mean')
#    2077     ax3.axvline(x=flux_med3,color='k',label='median')
#
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6589             # this will automatically overwrite bins,
#    6590             # so that each histogram uses the same bins
# -> 6591             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6592             m = m.astype(float)  # causes problems later if it's an int
#    6593             if mlast is None:
#
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     763             # The index computation is not guaranteed to give exactly
#     764             # consistent results within ~1 ULP of the bin edges.
# --> 765             decrement = tmp_a_data < bin_edges[indices]
#     766             indices[decrement] -= 1
#     767             # The last bin includes the right edge. The other bins do not.
#
# IndexError: index -9223372036854775808 is out of bounds for axis 1 with size 2
