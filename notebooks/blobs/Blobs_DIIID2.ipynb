# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
import pylab as py
import sys
import numpy.ma as ma
from decimal import Decimal
import sqlite3
import pandas as pd
import os
from importlib import reload
from matplotlib import animation, rc
import matplotlib.animation as animation
from matplotlib.ticker import FormatStrFormatter
import types
from IPython.display import HTML
import blobs
import warnings

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
H = blobs.blob_history(0,289)

# %%
x =  np.arange(0,blobs.psi.shape[0],1)
y = np.arange(0,blobs.psi.shape[1],1)
X,Y = np.meshgrid(x,y)
levels = [0.9,0.95,1.0,1.05]
plt.contour(X[:],Y[:],blobs.psi[X[:],Y[:]],levels)
plt.show()

# %%
blobs.area_dist(0,289)

# %%
blobs.amplitude_dist(0,289)

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
blobs.size_dist_nrs(0,289)
# Out:
# /global/u1/g/giannos/xgc_python_dir/blobs.py:1513: RuntimeWarning: invalid value encountered in arcsin
#   Ang1 = np.arcsin((level+1.)/(peak+1.))
# Number of blobs: 741

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
blobs.birth_distribution(H)

# %%
blobs.vel_vs_pos(H)
# Out:
# /usr/common/software/python/3.7-anaconda-2019.07/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/common/software/python/3.7-anaconda-2019.07/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
arr_mid = np.load('/global/cscratch1/sd/giannos/ti255_arrays/ne_mid.npy')

# %%
blobs.flux_vs_pos(arr_mid,H)
