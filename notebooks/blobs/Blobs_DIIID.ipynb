# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
import pylab as py
import sys
import numpy.ma as ma
from decimal import Decimal
import sqlite3
import pandas as pd
import os
from importlib import reload
from matplotlib import animation, rc
import matplotlib.animation as animationη
from matplotlib.ticker import FormatStrFormatter
import types
from IPython.display import HTML
import blobs
import warnings

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
H = blobs.blob_history(500,689)

# %%
blobs.area_dist(500,689)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
blobs.amplitude_dist(500,689)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
blobs.position_distribution(500,689)
# Out:
# /global/common/cori/software/python/3.6-anaconda-5.2/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
blobs.vel_vs_pos(H)

# %%
arr_mid = np.load('/global/cscratch1/sd/giannos/ti255_arrays/ne_mid.npy')

# %%
blobs.flux_vs_pos(arr_mid,H)
