# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
import pylab as py
import sys
import numpy.ma as ma
from decimal import Decimal
import sqlite3
import pandas as pd
import os
from importlib import reload
from matplotlib import animation, rc
import matplotlib.animation as animationη
from matplotlib.ticker import FormatStrFormatter
import types
from IPython.display import HTML
import blobs
import warnings

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
H = blobs.blob_history(0,499)

# %%
blobs.area_dist(0,499)

# %%
blobs.amplitude_dist(0,499)

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
blobs.size_dist_nrs(0,499)
# Out:
# /global/u1/g/giannos/xgc_python_dir/blobs.py:1513: RuntimeWarning: invalid value encountered in arcsin
#   Ang1 = np.arcsin((level+1.)/(peak+1.))
# Number of blobs: 1332

# %%
blobs.birth_distribution(H)

# %%
blobs.position_distribution(0,499)

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
blobs.vel_vs_pos(H)
# Out:
# /usr/common/software/python/3.7-anaconda-2019.07/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/common/software/python/3.7-anaconda-2019.07/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
blobs.total_velocity_distributions(H)

# %%
reload(blobs)
# Out:
# <module 'blobs' from '/global/u1/g/giannos/xgc_python_dir/blobs.py'>

# %%
blobs.amplitude_velocity(H)

# %%
blobs.birth_distribution(H)

# %%
blobs.vel_vs_pol_pos(H)

# %%
ne_mid = np.load('/global/cscratch1/sd/giannos/ti262_arrays/ne_mid.npy')

# %%
blobs.flux_vs_pos(ne_mid,H)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-8bbe19eceeae> in <module>
# ----> 1 blobs.flux_vs_pos(ne_mid,H)
#
# NameError: name 'ne_mid' is not defined
