# %%
# %matplotlib inline
import numpy as np
#%config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as mtick
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from decimal import Decimal
import scipy
from scipy import special
from scipy.integrate import trapz, simps
plt.style.use('classic')
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'heavy'
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12

# %%
ne = np.load("C:\\Users\\giann\\OneDrive\\Desktop\\Python_scrpts\\ti255\\ti255_ne_short.npy")

# %%
ne.shape
# Out:
# (200, 32, 100, 100)

# %%
ne[np.isnan(ne)] = 0
ne_tor = ne.mean(axis = 1)
ne_tt = ne_tor.mean(axis = 0)
dne = np.ones((ne.shape[0],ne.shape[1],ne.shape[2],ne.shape[3]))
for time in range(0,ne.shape[0]):
    for plane in range(0,ne.shape[1]):
        dne[time,plane,:,:] = ne[time,plane,:,:] - ne_tt[:,:]
dne.shape
# Out:
# (200, 32, 100, 100)

# %%
dnrms = np.ones((ne.shape[0],ne.shape[1],ne.shape[2],ne.shape[3]))
for time in range(0,ne.shape[0]):
    for plane in range(0,ne.shape[1]):
        dnrms[time,plane,:,:] = np.sqrt(np.power(ne[time,plane,:,:] - ne_tor[time,:,:],2))
dnrms.shape
# Out:
# (200, 32, 100, 100)

# %%
plt.imshow(dne[100,0,30:70,0:100])
plt.show()

# %%
plt.imshow(dnrms[0,0,0:100,0:100])
plt.show()

# %%
plt.imshow(ne[680,:,0,0:100])
plt.show()

# %%
plt.imshow(ne[680,40:65,0,0:100])
plt.show()

# %%
dt = 2.3e-7
T = [x*dt for x in range(200)]
N_t = len(T)
T_t = dt*N_t
df_t = 1/T_t
dw_t = 2*np.pi/T_t
freq_t = np.fft.fftfreq(len(T))

# %%
tm = [x for x in range(ne.shape[0])]
gamma = 0.040
y = [gamma*tip +35.0 for tip in tm]
plt.plot(tm[:200],np.log(dnerms[:200,50,5,60]))
plt.plot(tm[0:250],y[0:250],'r*')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-af723096f942> in <module>()
#       2 gamma = 0.040
#       3 y = [gamma*tip +35.0 for tip in tm]
# ----> 4 plt.plot(tm[:200],np.log(dnerms[:200,50,5,60]))
#       5 plt.plot(tm[0:250],y[0:250],'r*')
#       6 plt.show()
#
# NameError: name 'dnerms' is not defined

# %%
growth = gamma/dt
print("growth rate (1/s) = ", growth)
# Out:
# growth rate (1/s) =  173913.04347826086

# %%
dR = (2.27-2.19)/100
dZ = (0.25+0.25)/100
R = [2.19+60*dR+ip*dR for ip in range(10)]
Z = [-0.25+38*dZ+ip*dZ for ip in range(32)]
rho_i=2.0e-3

# %%
N_z = len(Z)
dt_z = dZ
T_z = dt_z*N_z
df_z = 1/T_z
dw_z = 2*np.pi/T_z
freq_z = np.fft.fftfreq(len(Z))

# %%
ne_tor.shape
# Out:
# (200, 100, 100)

# %%
#fou_z = np.fft.fft(pot_tt[0:80,85]-np.mean(pot_tt[0:80,85]))
#fou_z = np.fft.fft(pot_tor[190,20:40,85]-np.mean(pot_tt[20:40,85]))
fou_z = np.fft.fft((ne_tor[180,38:70,58]-ne_tt[38:70,58])/np.mean(ne_tt[38:70,58]))
plt.semilogy(abs(freq_z*N_z*dw_z)*rho_i,abs(fou_z**2),'*-')
print('kz',abs(freq_z*N_z*dw_z)*rho_i)
plt.axvline(x=0.246,color='r')
#plt.ylim(1.0e2,1.0e6)
plt.title(r'Spectrum in $z$')
plt.xlabel(r'$k_z \rho_i$')
plt.show()
# Out:
# kz [0.         0.07853982 0.15707963 0.23561945 0.31415927 0.39269908
#  0.4712389  0.54977871 0.62831853 0.70685835 0.78539816 0.86393798
#  0.9424778  1.02101761 1.09955743 1.17809725 1.25663706 1.17809725
#  1.09955743 1.02101761 0.9424778  0.86393798 0.78539816 0.70685835
#  0.62831853 0.54977871 0.4712389  0.39269908 0.31415927 0.23561945
#  0.15707963 0.07853982]

# %%
N_r = len(R)
dt_r = dR
T_r = dt_r*N_r
df_r = 1/T_r
dw_r = 2*np.pi/T_r
freq_r = np.fft.fftfreq(len(R))

# %%
fou_r = np.fft.fft(ne_tor[680,50,60:70]-np.mean(ne_tt[50,60:70]))
plt.semilogy(abs(freq_r*N_r*dw_r)*rho_i,abs(fou_r)**2,'*')
print('kr',abs(freq_r*N_r*dw_r)*rho_i)
plt.axvline(x=0.246,color='r')
#plt.ylim(1.0e2,1.0e6)
plt.title(r'Spectrum in $r$')
plt.xlabel(r'$k_r \rho_i$')
plt.show()
# Out:
# kr [0.         1.57079633 3.14159265 4.71238898 6.28318531 7.85398163
#  6.28318531 4.71238898 3.14159265 1.57079633]

# %%
dt = 2.3e-7
T = [x*dt for x in range(200)]
N_t = len(T)
T_t = dt*N_t
df_t = 1/T_t
dw_t = 2*np.pi/T_t
freq_t = np.fft.fftfreq(len(T))

# %%
#fou_t = np.fft.fft(dnrms[490:,50,0,60])
fou_t = np.fft.fft(ne_tor[490:,50,60]-np.mean(ne_tt[50,60]))
plt.plot(abs(freq_t*N_t*dw_t)/1000,abs(fou_t)**2,'*-')
plt.xlabel(r'$\left(\frac{rad}{sec}\right)\times 10^3$')
plt.title(r'Spectrum in time')
plt.ylim(1.0e35,3.0e40)
plt.xlim(0,5000)
#plt.xlim(72000,78000)
plt.axvline(x=4090,color='r')#651 kHz
#plt.axvline(x=4020,color='b')#640 kHz
plt.show()

# %%
X = abs(freq_z*N_z*dw_z)*rho_i
Y = abs(freq_t*N_t*dw_t)
XX,YY = np.meshgrid(X,Y)

# %%
fou_z = np.fft.fft2(ne_tor[:,50:70,60]-np.mean(ne_tt[50:70,60]),axes=(-2,-1))
F2 = np.fft.fftshift(fou_z**2)
F = abs(fou_z**2)
F2 = abs(F2)

# %%
fig, ax = plt.subplots(figsize=(6,6))
pos=ax.pcolor(XX[:,:],YY[:,:],abs(F.T)/1.0e21,cmap='viridis_r',vmax=0.2)
#ax.set_aspect(1000)
plt.xlim(0,1.0)
plt.ylim(0,6000)
plt.ylabel(r'$\left(\frac{rad}{sec}\right)\times 10^3$')
plt.xlabel(r'$k_z \rho_i$')
fig.colorbar(pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6781fe053191> in <module>()
#       1 fig, ax = plt.subplots(figsize=(6,6))
# ----> 2 pos=ax.pcolor(XX[:,:],YY[:,:],abs(F.T)/1.0e21,cmap='viridis_r',vmax=0.2)
#       3 #ax.set_aspect(1000)
#       4 plt.xlim(0,1.0)
#       5 plt.ylim(0,6000)
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolor(self, *args, **kwargs)
#    5740         vmax = kwargs.pop('vmax', None)
#    5741
# -> 5742         X, Y, C = self._pcolorargs('pcolor', *args, allmatch=False)
#    5743         Ny, Nx = X.shape
#    5744
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _pcolorargs(funcname, *args, **kw)
#    5588                 raise TypeError('Dimensions of C %s are incompatible with'
#    5589                                 ' X (%d) and/or Y (%d); see help(%s)' % (
# -> 5590                                     C.shape, Nx, Ny, funcname))
#    5591             C = C[:Ny - 1, :Nx - 1]
#    5592         C = cbook.safe_masked_invalid(C)
#
# TypeError: Dimensions of C (20, 690) are incompatible with X (25) and/or Y (200); see help(pcolor)
