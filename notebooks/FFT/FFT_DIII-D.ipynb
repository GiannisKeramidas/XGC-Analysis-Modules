# %%
# %matplotlib inline
import numpy as np
#%config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as mtick
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from decimal import Decimal
import scipy
from scipy import special
from scipy.integrate import trapz, simps
plt.style.use('classic')
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'heavy'
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12

# %%
def f(n,t):
    return n*np.cos(n*20*np.pi*t)

# %%
t = np.arange(0,0.5,0.0005)
f0 = f(0,t)
f1 = f(1,t)
f2 = f(2,t)
f3 = f(3,t)
f4 = f(4,t)
f5 = f(5,t)
g = f0+f1+f2+f3+f4+f5

# %%
plt.figure()
plt.plot(t,g)
plt.show()

# %%
N = 1000
dt = 0.005
T = dt*N
df = 1/T
dw = 2*np.pi/T

# %%
g=np.asarray(g)
fou = np.fft.fft(g)
#fou = np.fft.fftshift(fou)
freq = np.fft.fftfreq(t.shape[-1])

# %%
plt.plot(abs(10*freq*N*df),abs(fou)**2)
plt.xlim(0,60)
plt.show()

# %%
pot = np.load("C:\\Users\\giann\\OneDrive\\Desktop\\Python_scrpts\\ti255\\pot_all_midplane.npy")
pot[np.isnan(pot)] = 0
pot_tor = pot.mean(axis = 2)
pot_tt = pot_tor.mean(axis = 0)
dpot = np.ones((pot.shape[0],pot.shape[1],pot.shape[2],pot.shape[3]))
for time in range(0,pot.shape[0]):
    for plane in range(0,pot.shape[2]):
        dpot[time,:,plane,:] = pot[time,:,plane,:] - pot_tt[:,:]
dpot.shape
# Out:
# (200, 100, 32, 100)

# %%
ne = np.load("C:\\Users\\giann\\OneDrive\\Desktop\\Python_scrpts\\ti255\\ne_ti255_mid.npy")

# %%
ne[np.isnan(ne)] = 0
ne_tor = ne.mean(axis = 2)
dnerms = np.ones((ne.shape[0],ne.shape[1],ne.shape[2],ne.shape[3]))
for time in range(0,ne.shape[0]):
    for plane in range(0,ne.shape[2]):
        dnerms[time,:,plane,:] = np.sqrt(np.power(ne[time,:,plane,:] - ne_tor[time,:,:],2))

# %%
plt.imshow(ne[600,:,0,:])
plt.show()

# %%
dt = 2.3e-7
T = [x*dt for x in range(200)]
N_t = len(T)
T_t = dt*N_t
df_t = 1/T_t
dw_t = 2*np.pi/T_t
freq_t = np.fft.fftfreq(len(T))

# %%
tm = [x for x in range(ne.shape[0])]
gamma = 0.040
y = [gamma*tip +35.0 for tip in tm]
plt.plot(tm[:200],np.log(dnerms[:200,50,5,60]))
plt.plot(tm[0:250],y[0:250],'r*')
plt.show()

# %%
growth = gamma/dt
print("growth rate (1/s) = ", growth)
# Out:
# growth rate (1/s) =  173913.04347826086

# %%
plt.imshow(dpot[180,0:50,0,0:100])
plt.show()

# %%
dR = (2.26-2.15)/100
dZ = (0.55+0.28)/100
R = [2.15+ip*dR for ip in range(100)]
Z = [-0.28+ip*dZ for ip in range(100)]
R[99]
Z[99]
# Out:
# 0.5417

# %%
dR = (2.26-2.15)/100
dZ = (0.55+0.28)/100
R = [2.15+ip*dR for ip in range(100)]
Z = [-0.28+ip*dZ for ip in range(100)]
fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(dpot[190,:,9,0:100],extent=[2.15,2.26,-0.28,0.55])
ax.set_aspect(0.2)
#plt.ylim(0.25,0.35)
#plt.xlim(2.22,2.25)
plt.xlabel("R (m)")
plt.ylabel("Z (m)")
plt.show()

# %%
plt.plot(R[20:],pot_tt[38,20:])
plt.show()

# %%
plt.plot(Z[0:80],pot_tt[0:80,70])
plt.show()

# %%
N_z = len(Z[0:80])
dt_z = dZ
T_z = dt_z*N_z
df_z = 1/T_z
dw_z = 2*np.pi/T_z
freq_z = np.fft.fftfreq(len(Z[0:80]))

# %%
fou_z = np.fft.fft(pot_tt[0:80,85]-np.mean(pot_tt[0:80,85]))
plt.plot(abs(freq_z*N_z*dw_z),abs(fou_z)**2)
plt.xlim(0,50)
plt.show()

# %%
N_r = len(R[10:])
dt_r = dR
T_r = dt_r*N_r
df_r = 1/T_r
dw_r = 2*np.pi/T_r
freq_r = np.fft.fftfreq(len(R[10:]))

# %%
t_f_r = []
for time in range(pot.shape[0]):
    for plane in range(pot.shape[2]):
        t_f_r.append(abs(np.fft.fft(dpot[time,40,plane,10:]-np.mean(dpot[time,40,plane,10:])))**2)
tfr = np.asarray(t_f_r)
tfr = np.reshape(tfr,(200,32,90))
tfr_tor = tfr.mean(axis=1)
tfr_avg = tfr_tor.mean(axis=0)
plt.plot(abs(freq_r*N_r*dw_r),tfr_avg)
plt.xlim(60,65)
plt.show()

# %%
t_f_z = []
for time in range(pot.shape[0]):
    for plane in range(pot.shape[2]):
        t_f_z.append(abs(np.fft.fft(dpot[time,0:80,plane,85]-np.mean(dpot[time,0:80,plane,85]))**2))
tfz = np.asarray(t_f_z)
tfz = np.reshape(tfz,(200,32,80))
tfz_tor = tfz.mean(axis=1)
tfz_avg = tfz_tor.mean(axis=0)
plt.plot(abs(freq_z*N_z*dw_z),tfz_avg)
plt.xlim(100,120)
plt.show()

# %%
fou_r = np.fft.fft(pot_tt[42,10:]-np.mean(pot_tt[42,10:]))
#fou_r = []
#for i in range(35,45):
    #fou_r.append(np.fft.fft(pot_tt[i,10:]))
#fou_r = np.asarray(fou_r)
#fou_r = fou_r.mean(axis=0)
#fou_r = np.fft.fftshift(fou_r)
plt.plot(abs(freq_r*N_r*dw_r),abs(fou_r)**2)
plt.xlim(100,130)
plt.show()

# %%
plt.imshow(pot_tt)
plt.show()

# %%
first1 = np.mean(dpot[180,:,0,:],axis=0)
sec2 = np.mean(first1)
F3 = np.fft.fft2(dpot[180,:,0,:]-sec)/(100*100)
F3 = np.fft.fftshift(F3)
P3 = abs(F3)**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5b38d9e21f2c> in <module>()
#       1 first1 = np.mean(dpot[180,:,0,:],axis=0)
#       2 sec2 = np.mean(first1)
# ----> 3 F3 = np.fft.fft2(dpot[180,:,0,:]-sec)/(100*100)
#       4 F3 = np.fft.fftshift(F3)
#       5 P3 = abs(F3)**2
#
# NameError: name 'sec' is not defined

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(P3)
plt.xlim(45,55)
plt.ylim(45,55)
#ax.colorbar()
ax.set_aspect(0.6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-1e7ae056ae87> in <module>()
#       1 fig, ax = plt.subplots(figsize=(6,6))
# ----> 2 ax.imshow(P3)
#       3 plt.xlim(45,55)
#       4 plt.ylim(45,55)
#       5 #ax.colorbar()
#
# NameError: name 'P3' is not defined

# %%
first = np.mean(pot_tt[:,:],axis=0)
sec = np.mean(first)
F2 = np.fft.fft2(pot_tt[:,:]-sec)/(100*100)
F2 = np.fft.fftshift(F2)
P2 = abs(F2)**2

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(P2)
plt.xlim(40,60)
plt.ylim(40,60)
#ax.colorbar()
ax.set_aspect(0.6)
plt.show()

# %%
k_perp = np.sqrt(60**2 + 9**2)
rho_i = 1.9e-3
arg = (k_perp**2)*(rho_i**2)
arg2 = k_perp*rho_i
print(arg,arg2)
# Out:
# 0.01328841 0.115275365972

# %%
scipy.special.jv(0,arg)
# Out:
# 0.99995585502712092

# %%
scipy.special.jn(0,arg2)
# Out:
# 0.99668065557302399

# %%
scipy.special.ive(0,arg)
# Out:
# 0.98684305433227237

# %%
k_perpt = np.sqrt(64**2 + 105**2)
rho_i = 1.9e-3
argt = (k_perpt**2)*(rho_i**2)
#arg2 = k_perp*rho_i
print(k_perpt)
# Out:
# 122.967475375

# %%
scipy.special.ive(0,argt)
# Out:
# 0.94758179485501814

# %%
dt = 2.3e-7
T = [x*dt for x in range(200)]
N_t = len(T)
T_t = dt*N_t
df_t = 1/T_t
dw_t = 2*np.pi/T_t
freq_t = np.fft.fftfreq(len(T))

# %%
fou_t = np.fft.fft(dpot[:,40,0,80])
plt.plot(abs(freq_t*N_t*dw_t),abs(fou_t)**2)
#plt.xlim(72000,78000)
#plt.axvline(x=74700)
plt.show()

# %%
tm = [x for x in range(dpot.shape[0])]
gamma = 0.033
y = [gamma*tip +38.0 for tip in tm]
plt.plot(tm[:],np.log(dpotrms[:,50,5,60]))
#plt.plot(tm[0:250],y[0:250],'r*')
#plt.ylim(0,1e20)
plt.show()

# %%
frequency = 1500000/(2*np.pi)

# %%
frequency
# Out:
# 238732.414637843
